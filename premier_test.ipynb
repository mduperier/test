# %%
print("hello world")
# Out:
# hello world

# %%
def ma_fonction(x, y=0):
    return x + y

# %%
ma_fonction(2, 3)
# Out:
# 5

# %%
liste = [x**2 for x in range(10) if x % 2 == 0]

# %%
liste
# Out:
# [0, 4, 16, 36, 64]

# %%
import numpy as np

a = np.array([1,2,3])
np.mean(a)
# Out:
# np.float64(2.0)

# %%
np.dot(a, a)
# Out:
# np.int64(14)

# %%
import pandas as pd

df = pd.DataFrame({
    "age": [25, 30],
    "ville": ["Paris", "Lille"]
})

# %%
df["age"]
# Out:
# 0    25
# 1    30
# Name: age, dtype: int64

# %%
df.loc[0]
# Out:
# age         25
# ville    Paris
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# age         25
# ville    Paris
# Name: 0, dtype: object

# %%
df[df["age"] > 26]
# Out:
#    age  ville
# 1   30  Lille

# %%
df
# Out:
#    age  ville
# 0   25  Paris
# 1   30  Lille

# %%
df.groupby("ville")["age"].mean()
# Out:
# ville
# Lille    30.0
# Paris    25.0
# Name: age, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data.csv")

df = df.dropna()
df = df[df["age"] > 18]

result = df.groupby("ville")["salaire"].mean()

result.plot(kind="bar")
plt.show()

# %%
df_merge = pd.merge(df1, df2, on="id", how="inner")
